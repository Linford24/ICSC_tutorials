# %%
"""
## FUNCTIONS

In computer programming, there's a syntax for writing functions which is very similar to functions in mathematics.

In mathematics, the f(x) notation is used where,
  f = function
  x = input of the function

In simple terms, f performs an activity using a tool called x.

So if f(x) = 2x + 5, then
  f performs an activity which involves multiplying the tool x by 2 and adding the result to 5.

  If x = 3, thus, the tool is specified as 3 then,
  f(3) would mean f performs an activity/function which 
  multiplies 2 by 3 and adds the result to 5
  => 2 * 3 + 5 
  => 6 + 5
  = 11

  finally, f(3) = 11

The same example can be replicated with g(x, y) = 2y + 3x
 If g(3, 4)
 => 2 * 4 + 3 * 3
 => 8 + 9
 = 17

 g(x, y) = 17

 This same principle is applied in wrting functions in computer programming.
 f(x) = 2x + 5 can be written in code as:
 def f(x):
    return 2*x + 5

 f(3) would return the same answer 11.

 g(x,y) can be written as:
 def g(x, y):
    return 2 * y + 3 * x

 g(3, 4) would return 17 as well.

 Functions in programming differ from functions in mathematics by a few features:
 def, : and return

 For every function in programming, it starts with
 def followed by the name of the function...suppose we want to change f(x) to myfirstfunction(x), we would write this:

 def myfirstfunction(x) follwed by a colon which tells the computer to pay attention to what follows..just as colon is used in English to add another piece of a sentence to the first part, it is used the same way in prograaming. The colon allows the programmer to define the instructions/activity he/she wants the function to perform.

 def myfirstfunction(x):
    2 * x + 5 

the function above is correct but would not show us the answer unless 'return' is added to the expression in after the colon. 
It's similar to paying your school fees and not requesting for a receipt. The fees have already been paid but the receipt to show as confirmation wouldnt be with you because you never requested for it.

In the same way, when we call the function, myfirstfunction(x)...

calling a function is a programming jargon for running the code in a function and it is done by writing the function name and valid arguments... arguments refer to the inputs you put into function.

For example, the argument for myfirstfuntion(x) is x, those for g(x, y) are x and y.

Back to the function definition below..

  def myfirstfunction(x):
      2 * x + 5 

myfirstfunction(10)...which is the same as myfirstfunction(x = 10) would go through this process:
  => 2 * 10 + 5
  => 20 + 5
  = 25

  And the final result 25 would be stored in the computer's memory but never displayed like the receipt you never asked for.
To display the result, there is the need to add 'return' command to the activity being performed. Thus,
   
   def myfirstfunction(x):
      return 2 * x + 5 

Now, myfirstfunction(10) goes through this process
  => 2 * 10 + 5
  => 20 + 5
  = 25
  return 25
So 25 gets printed out.

Let's take another example of function. We will name this function myfullname and it takes two arguments, firstname and surname and returns a new variable called fullname.

A variable is a custom name a user gives to any data type. We have already mentioned the main data types in python programming are:
 string, integer, float, list, dictionaries, tuples, boolean (True/ False) and comparison operators.

 So a variable name can be given to any of these names. For example,

- Variable assigned to strings
     myname = "Linford"
     myschoolnumber = "BV241"

- Variable assigned to float and integer respectively
    schoolfees = 900.00
    lastnumberofCBs = 1270

- Variable assigned to list
    hallsinowass = ["John", "Luke", "Mark"]

- Variable assigned to dictionaries
    endingnumbersinhalls = {
           "John": 1, "Mark": 3, "Luke": 4, "Matthew": 2
  }
 
Now let's continue with the function creation.....

Let's take another example of function. We will name this function myfullname and it takes two arguments, firstname and surname and returns a new variable called fullname.

 def myfullname(firstname, surname):
     fullname = firstname + surname
     return fullname

In this function called myfullname which takes two arguments, firstname and surname, we are creating a new variable called fullname which adds firstname to surname and assigns the results to fullname. Then we finally return fullname.

The same function can be rewritten as

def myfullname(x, y):
    z = x + y
    return z

Calling the function, myfullname("Elon", "Musk") would go through this process,
 => myfullname(firstname="Elon", surname="Musk")
 => fullname = firstname + surname
 => where firstname="Elon", surname="Musk"
 => fullname = "Elon" + "Musk"
 => fullname = "ElonMusk"
 finally the myfunction("Elon", "Musk") returns "ElonMusk"

But you would notice there is no space between Elon and Musk, both are combined. Lets reconstruct the function to include space between the firstname and surname.

  def myfullname(firstname, surname):
     fullname = firstname + " " + surname
     return fullname
 We add space by inserting double quote and spacin the first and last quotes.

 Now calling myfullname("Elon", "Musk") goes through this process
   => myfullname(firstname="Elon", surname="Musk")
   => fullname = firstname + " " + surname
   => where firstname="Elon", surname="Musk"
   => fullname = "Elon" + " " + "Musk"
   => fullname = "Elon Musk"
    finally the myfunction("Elon", "Musk") returns "Elon Musk"

Now let's create  our last function called studentprofile. This function takes as argument my class and school number and house.
Then prints, "I am --schoolnumber-- in --class-- and --house--"

 def studentprofile(schoolnumber, class, house):
      final_sentence = "I am" + " " + schoolnumber + " " + "in" + " " + class + " " + "and" + " " + house
      return final_sentence

 Calling the function...
   studentprofile("BV241", "Science 8", "John") 
   => studentprofile(schoolnumber="BV241", class="Science 8", house="John")
   => final_sentence = "I am" + " " + schoolnumber + " " + "in" + " " + class + " " + "and" + " " + house
   => where schoolnumber="BV241", class="Science 8", house="John"
   => final_sentence = "I am" + " " + "BV241" + " " + "in" + " " + "Science 8" + " " + "and" + " " + "John"
   => final_sentence = "I am BV241 in Science 8 and John"

   so studentprofile("BV241", "Science 8", "John") returns "I am BV241 in Science 8 and John"

Tasks:
 - Create functions to perform any activities in mind.

"""

# %%
"""
## CONDITIONAL FLOWS

  # If...else

In English the most common way to express a conditional statement is through If clause.
A typical example, If OWASS wins this year's nsmq, we will make a lot of noise".
This statement can be broken in two parts:
  - The Antecedent(condition):
     If Owass wins this year's nsmq

  - The Consequent(result):
     we will make a lot of noise.

This same principle is carried over to programming where If statements are used to express conditions.
So the sentence can be written in code as:
 Let's create a variable called owass_has_won_nsmq

owass_has_won_nsmq = True
 if owass_has_won_nsmq == True:
    print("we will make a lot of noise")
 else:
    print("atanfo anya yen")

This particular if statement will print "we will make a lot of noise" since owass_has_won_nsmq variable is True.

We can change the condition so our enemies get us.
 by changing the value of owass_has_won_nsmq = False

i -  if owass_has_won_nsmq == True:
        print("we will make a lot of noise")
     else:
        print("atanfo anya yen")

  This same if statement can be reconstructed as:
ii -  if owass_has_won_nsmq != True:
        print("atanfo anya yen")
      else:
        print("we will make a lot of noise")

Both i and ii would print the same results "atanfo anya yen" since they meet the same condition.
However in i, the statement below the "else" condition is printed since the condition is false so the statement under the if statement is skipped.
But in ii, the statement below the "if" condition is printed since the condition is true....so if the condition for the if session is true,
the statement under if is printed but if the condition is false, the statement under else is printed.

Let's take another example, we want to assign a house to each student based on their school number. We will introduce an additional syntax
for expressing conditionin Python called "elif".

Considering the example below:

owass_has_won_nsmq = True
 
 if owass_has_won_nsmq == True:
    print("we will make a lot of noise")
 else:
    print("atanfo anya yen")

## The above expression only covers two conditions, either owass wins or loses the nsmq, so "if" and "else" alone are sufficient to capture both
  conditions. 

However if we want to express more than two conditions say, what happens when owass loses but st.louis wins, or what happens if both prempeh and
presec loses but owass wins. Expressing such numerous conditions would require the "elif" statement.

# If...elif...else

Let's express this condition what happens if both prempeh and presec loses but owass wins

owass_has_won_nsmq = True
presec_has_won_nsmq = False
pc_has_won_nsmq = False

   if presec_has_won_nsmq == True:
      print("Presec has won over 10 nsmq titles")
   elif pc_has_won_nsmq == True:
      print("PC has won their 5th nsmq title")
   elif owass_has_won_nsmq == True:
      print("Owass has won the long-awaited 3rd nsmq title")
   else:
      print("Neither Owass nor PC nor Presec won the 2025 nsmq national championship")

## The statement above would print "Owass has won the long-awaited 3rd nsmq title" since only that condition is true. But notice how we expressed
four conditions...
   the first: If presec_has_won_nsmq == True, pc_has_won_nsmq == False, owass_has_won_nsmq == False
   
   the second: If pc_has_won_nsmq == True, presec_has_won_nsmq == False, owass_has_won_nsmq == False
   
   the third: If owass_has_won_nsmq == True, presec_has_won_nsmq == False, pc_has_won_nsmq == False
   
   the last: If presec_has_won_nsmq == False, pc_has_won_nsmq == False, owass_has_won_nsmq == False

Whenever you want to express more than two conditions, the "elif" statement is very crucial.

# %%
"""
Let's take an exmaple that uses both functions and conditional flows (if..elif..else)

 We are writing a function that takes a student's schoolnumber and prints the house he will be in.

 for instance, if the function name is house_allocator("BV241")... 
    the results should be, "You will be in John".

 def house_allocator(schoolnumber):
    if schoolnumber.endswith("1"):
        print("You will stay at John")
    elif schoolnumber.endswith("2"):
        print("You will stay at Matthew")
    elif schoolnumber.endswith("3"):
        print("You will stay at Mark")
    elif schoolnumber.endswith("4"):
        print("You will stay at Luke")
    elif schoolnumber.endswith("5"):
        print("You will stay at Paul")
    elif schoolnumber.endswith("6"):
        print("You will stay at Peters")
    elif schoolnumber.endswith("7"):
        print("You will stay at James")
    elif schoolnumber.endswith("8"):
        print("You will stay at Andrew")
    elif schoolnumber.endswith("9"):
        print("You will stay at Philip")
    else:
        print("You will stay at Thomas")


Call this function with different school numbers and observe the results to confirm the function's accuracy
"""

# %%
"""
## CONDITIONAL FLOWS II

  # For...loop
  
  In the previous conditional flow, we dealt with if...elif..and else which deal with a condition at a time.
  But there's another syntax for dealing with conditions. Using the same house allocation example, 
  instead of having to call the function with a schoolnumber each time, like house_allocator("CB 130"),
  we could provide a list and the function will move through each item inn the list and assign it to the list of students
  in a particular house.

  Thus, let's create a list of student numbers and assign to the variable name, student_list,

  student_list = ["CB 181", "CB 182","CB 183","CB 184", "CB 185", "CB 186", "CB 187", "CB 188", "CB 189", "CB 180"]

  for student in student_list:
    if student.endswith("1"):
        print(f"{student} will stay at John")
    elif student.endswith("2"):
        print(f"{student} will stay at Matthew")
    elif student.endswith("3"):
        print(f"{student} will stay at Mark")
    elif student.endswith("4"):
        print(f"{student} will stay at Luke")
    elif student.endswith("5"):
        print(f"{student} will stay at Paul")
    elif student.endswith("6"):
        print(f"{student} will stay at Peters")
    elif student.endswith("7"):
        print(f"{student} will stay at James")
    elif student.endswith("8"):
        print(f"{student} will stay at Andrew")
    elif student.endswith("9"):
        print(f"{student} will stay at Philip")
    else:
        print(f"{student} will stay at Thomas")

Let's break the code down line after line

- for student_number in student_list:
   - already we have defined student_list as a variable containing a list of student numbers
       student = ["CB 181", "CB 182","CB 183","CB 184", "CB 185", "CB 186", "CB 187", "CB 188", "CB 189", "CB 180"]
   - so the line implies for each item(student number) in student_list, do the pass it through the instructions after below the colon.
       so if the code was,
          - for student_number in student_list:
                print(student_number)

                The code will go to the first item which is "CB 181" and run, print("CB 181"), then

                it moves to the second item "CB 182" and run, print("CB 182"), then 

                it will continue till the last item "CB 180" and run print("CB 180").

    - this line of code picks each item in the student_list and runs the coe below on it.

- if student_number.endswith("1):
     print(f"{student_number} will stay at John")

     so the first item is picked, "CB 181"
     the "if" condition is run to check if student_number = "CB 181" really ends with 1
     if it does, then the statement below it is printed:

     "CB 181 will stay at John"

     then the code is started afresh from the "for student_number in student_list:"...
     but since we have already dealt with "CB 181", the second item which is "CB 182" will be picked.

- Then the code checks if student_number = "CB 182" ends with 1. This gives a false statement since 182 does not end
     with one. Therefore, the code moves to the second condition which is 

- elif student.endswith("2"):
        print(f"{student} will stay at Matthew")

    Since "CB 182" ends with 2, the statement below is printed:

    "CB 182 will stay at Matthew"

    then the code is started afresh from the beginning and the third item, "CB 183" is picked.

    this cycle goes on till the last item "CB 180" is picked..since it is the last item in the student list,
    the code stops after printing

    "CB 180 will stay at Thomas"

- This cycle of the code going up and down through a list using the "for" syntax is termed "for loop".
   So the code loops(iterates or moves through) all the items of the list provided and ends after it is done with the last item.

  

  student_numbers = ["CB 181", "CB 182","CB 183","CB 184", "CB 185", "CB 186", "CB 187", "CB 188", "CB 189", "CB 180",
                      "CB 191", "CB 192", "CB 193", "CB 194", "CB 195", "CB 196", "CB 197", "CB 198", "CB 199", "CB 190"
                      "CB 171, "CB 172", "CB 173", "CB 174", "CB 175", "CB 176", "CB 177", "CB 178", "CB 179", "CB 170"
                      "CB 161", "CB 162", "CB 163","CB 164", "CB 165", "CB 166", "CB 167", "CB 168", "CB 169", "CB 160"] 

  We want to write code that iterates(moves through) this list and assigns each student to the appropriate house.
  so let's create a variable for each of the houses
  john = []
  matthew = []
  luke = []
  mark = []
  paul = []
  peters = []
  philip = []
  james = []
  andrew = []
  thomas = []

  Let's create the function

  def house_allocator(student_list):
    for student in student_list:
        if student.endswith("1"):
            john.append(student)
        elif student.endswith("2"):
            matthew.append(student)
        elif student.endswith("3"):
            mark.append(student)
        elif student.endswith("4"):
            luke.append(student)
        elif student.endswith("5"):
            paul.append(student)
        elif student.endswith("6"):
            peters.append(student)
        elif student.endswith("7"):
            james.append(student)
        elif student.endswith("8"):
            andrew.append(student)
        elif student.endswith("9"):
            philip.append(student)
        else:
            thomas.append(student)
    return john, matthew, mark, luke, paul, peters, james, andrew, philip, thomas 


# the append() adds an item to a list
For example,
 owass_sports = ["football", "basketball"]
 if we want to add hockey to the list, owass_sports
 we do so:
 - owass_sports.append("hockey")

 then:
   owass_sports = ["football", "basketball", "hockey"]
 
calling the function: house_allocator(student_numbers) then returns:
   (['CB 181', 'CB 191', 'CB 171', 'CB 161'],
    ['CB 182', 'CB 192', 'CB 172', 'CB 162'],
    ['CB 183', 'CB 193', 'CB 173', 'CB 163'],
    ['CB 184', 'CB 194', 'CB 174', 'CB 164'],
    ['CB 185', 'CB 195', 'CB 175', 'CB 165'],
    ['CB 186', 'CB 196', 'CB 176', 'CB 166'],
    ['CB 187', 'CB 197', 'CB 177', 'CB 167'],
    ['CB 188', 'CB 198', 'CB 178', 'CB 168'],
    ['CB 189', 'CB 199', 'CB 179', 'CB 169'],
    ['CB 180', 'CB 190', 'CB 170', 'CB 160'])

    The results appear in the exact order we asked the function to return:
      john, matthew, mark, luke, paul, peters, james, andrew, philip, thomas
  

"""

# %%
"""
## CONDITIONAL FLOW III

The While...Loop

The while loop functions in a similar way as the for loop.
The difference is that, 
  - the for loop picks its starting and ending point from the provided iterable.
     An iterable is any item that contains multiple items which can be iterated or moved through. 
     Thus, an iterable contains more than one item. It could be a list or dictionary with one or more items.

  - the ending point of the while loop is specified directly just as the starting point.

Let's illustrate an example of while loop. We have 75 CBs, 130 CDs and 150 CEs.
We are allocating rooms to these students. 
Each room takes 30 students.
And there must be exactly 5 CBs, 10 CDs and 15 CEs in each room.

How many rooms would be filled?
How many CBs would remain without a room?
How many CDs would remain without a room?
How many CEs would remain without a room?

  def room_allocation(total_number_of_CBs, total_number_of_CDs, total_number_of_CEs):
      remaining_CBs = total_number_of_CBs
      remaining_CDs = total_number_of_CDs
      remaining_CEs = total_number_of_CEs
      full_rooms = 0

      while remaining_CBs >= 5 and remaining_CDs >= 10 and remaining_CEs >= 15:
          full_rooms += 1
          remaining_CBs = remaining_CBs - 5
          remaining_CDs = remaining_CDs - 10
          remaining_CEs = remaining_CEs - 15

      results = [full_rooms, remaining_CBs, remaining_CDs, remaining_CEs]
      return results

      
For this while...loop,
we start off by defining the starting points.

Since we are yet to assign any room to the appropriate number of students, it means every room is empty.

Let's create a variable called full_rooms which will indicate the number of rooms that are already filled.
At the start, 
   full_rooms = 0

   since no room has been filled with students.

The students remaining to be given a room at the beginning would also equal the total number of students to be given a room.
Thus, if 100 students are to be assigned a room, then the students without room at the beginning (or remaining students) would be 100 as well.

So let the total number of students to be assigned rooms be assigned to the variable, total_number_of_students
Let the students without room or waiting to be given rooms be assigned to the variable, remaining_students

So this will be the state of each variable at the beginning:
   full_rooms = 0
   total_number_of_CBs = 75
   remaining_CBs = total_number_of_CBs
   total_number_of_CDs = 130
   remaining_CDs = total_number_of_CDs
   total_number_of_CEs = 150
   remaining_CEs = total_number_of_CEs

   So these signify the starting point of the while loop.

Now the while loop starts off with these conditions:
  while remaining_CBs >= 5 and remaining_CDs >= 10 and remaining_CEs >= 15

  Thus, the ending points of the loop have been specified:
     - if remaining_CBs, thus, the number of CBs left are not up to 5 then stop sharing the room since the exact criteria cannot be met.
        there should be exactly 5 CBs in each room so if there are less irrespective of the number of CDs and CEs, we cannot continue sharing the room.

    - if remaining_CDs, thus, the number of CDs left are not up to 10 then stop sharing the room since the exact criteria cannot be met.
        there should be exactly 10 CDs in each room so if there are less irrespective of the number of CBs and CEs, we cannot continue sharing the room.

   - if remaining_CBs, thus, the number of CEs left are not up to 15 then stop sharing the room since the exact criteria cannot be met.
        there should be exactly 15 CBs in each room so if there are less irrespective of the number of CDs and CBs, we cannot continue sharing the room.

    So the loop starts running using the starting points which have the following states:

       full_rooms = 0
       total_number_of_CBs = 75
       remaining_CBs = total_number_of_CBs = 75
       total_number_of_CDs = 130
       remaining_CDs = total_number_of_CDs = 130
       total_number_of_CEs = 150
       remaining_CEs = total_number_of_CEs = 150

       if the condition remaining_CBs >= 5 and remaining_CDs >= 10 and remaining_CEs >= 15 is met:
          then it means 
             the remaining_CBs are at least 5 in mumber
             the remaining_CDs are at least 10 in mumber
             the remaining_CEs are at least 15 in mumber

             hence a full room can be assigned to them increasing the full_room to 1
             thus full_room += 1 means full_room which started as 0 + 1 = 1

             then the number of students given a room is subracted from the remaining students, 
             thus for the remaining CBs, they become short of 5 students
                 remaining_CBs = remaining_CBs - 5

             thus for the remaining CDs, they become short of 10 students
                 remaining_CDs = remaining_CDs - 10

             thus for the remaining CEs, they become short of 5 students
                 remaining_CES = remaining_CEs - 15

            then the loop restarts again with the new state of the variables which is:
               full_rooms = 1
               remaining_CBs = 75 - 5 = 70
               remaining_CDs = 130 - 10 = 120
               remaining_CEs = 150 - 15 = 135

        if the condition remaining_CBs >= 5 and remaining_CDs >= 10 and remaining_CEs >= 15 is met:
          then it means 
             the remaining_CBs are at least 5 in mumber
             the remaining_CDs are at least 10 in mumber
             the remaining_CEs are at least 15 in mumber

             hence a full room can be assigned to them increasing the full_room to 1
             thus full_room += 1 means full_room which started as 1 + 1 = 2

             then the number of students given a room is subracted from the remaining students, 
             thus for the remaining CBs, they become short of 5 students
                 remaining_CBs = 70 - 5 = 65

             thus for the remaining CDs, they become short of 10 students
                 remaining_CDs = 120 - 10 = 110

             thus for the remaining CEs, they become short of 5 students
                 remaining_CES = 135 - 15 = 120

         then the loop restarts again with the new state of the variables which is:
               full_rooms = 2
               remaining_CBs = 65 
               remaining_CDs = 110
               remaining_CEs = 120

    this loop continues till we reach a particular state where one of the 3 conditional variables is less than its required minimum...
    this state would occur after
               full_rooms = 10
               remaining_CBs = 25
               remaining_CDs = 30
               remaining_CEs = 0

            Since remaining CEs is less than 15, no more full room can be allocated, so the condition:

            while remaining_CBs >= 5 and remaining_CDs >= 10 and remaining_CEs >= 15 evaluates to false
              since remaining_CEs is not greater than or equal to 15.

              then the rest of the code outside the while loop runs:

              def room_allocation(total_number_of_CBs, total_number_of_CDs, total_number_of_CEs):
                 remaining_CBs = total_number_of_CBs
                 remaining_CDs = total_number_of_CDs
                 remaining_CEs = total_number_of_CEs
                 full_rooms = 0

                 while remaining_CBs >= 5 and remaining_CDs >= 10 and remaining_CEs >= 15:
                   full_rooms += 1
                   remaining_CBs = remaining_CBs - 5
                   remaining_CDs = remaining_CDs - 10
                   remaining_CEs = remaining_CEs - 15

                # The rest of the code outside the while loop
                 assigning the full rooms and remaining students to a variable named "results"
                 then the function returns the variable results
                
                results = [full_rooms, remaining_CBs, remaining_CDs, remaining_CEs]
                return results

     
         So the whole process discussed above happens when we run:
            room_allocation(75, 130, 150)
            
            we would get:
              [10, 25, 30, 0]

              thus, 
              [full_rooms, remaining_CBs, remaining_CDs, remaining_CEs]

              full_rooms = 10
              remaining_CBs = 25
              remaining_CDs = 30
              remaining_CEs = 10           
               
"""

# %%
"""
By the same analogy, try your hands on the question below:

A baker has a favorite cake recipe that requires precise amounts of ingredients: 
 - 100 units of flour and 
 - 50 units of sugar. 
 Your task is to help the baker to calculate:
• How many cakes can be made from a given number of flour and sugar units, for eg, 500 flour units and 300 sugar units.
• How much flour and sugar will remain unused after making as many cakes as possible

 Your function should return a list named results containing:
 - the number of cakes that can be made from the supplied units for instance 500 flour units and 300 sugar units,
 - the amount of leftover flour
 - the amount of leftover sugar.
"""
